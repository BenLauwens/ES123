# %%
include("chess.jl")
using ES123Chess
# Out:
# LoadError: ArgumentError: Module Crayons not found in current path.
# Run `Pkg.add("Crayons")` to install the Crayons package.
# while loading /home/jupyter/ES123/Projects/chess.jl, in expression starting on line 5
#
# Stacktrace:
#  [1] _require(::Symbol) at ./loading.jl:435
#  [2] require(::Symbol) at ./loading.jl:405
#  [3] include_from_node1(::String) at ./loading.jl:576

# %%
play(true)
# Out:
#  STDIN> done
